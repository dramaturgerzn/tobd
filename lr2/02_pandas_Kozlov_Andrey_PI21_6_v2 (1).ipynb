# %% [markdown]
# # Pandas

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 2: Библиотека Pandas"
# * https://pandas.pydata.org/docs/user_guide/index.html#
# * https://pandas.pydata.org/docs/reference/index.html
# * Уэс Маккини. Python и анализ данных

# %% [markdown]
# ## Задачи для совместного разбора

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 1. Загрузите данные из файла `sp500hst.txt` и обозначьте столбцы в соответствии с содержимым: `"date", "ticker", "open", "high", "low", "close", "volume"`.

# %%
#1 способ
dataset = np.loadtxt('sp500hst.txt', delimiter=',', dtype = str)
"""data_new = {'date' : dataset[:, 0],
           'ticker': dataset[:, 1],
           'open': dataset[:, 2],
           'high': dataset[:, 3],
           'low': dataset[:, 4],
           'close': dataset[:, 5],
           'volume': dataset[:, 6]}
print(pd.DataFrame(data_new))"""

#2 способ

pd1 = pd.DataFrame(dataset, columns = ["date", "ticker", "open", "high", "low", "close", "volume"])
pd1
# Out:
#             date ticker   open     high     low  close volume
# 0       20090821      A   25.6    25.61   25.22  25.55  34758
# 1       20090824      A  25.64    25.74   25.33   25.5  22247
# 2       20090825      A   25.5     25.7  25.225  25.34  30891
# 3       20090826      A  25.32  25.6425  25.145  25.48  33334
# 4       20090827      A   25.5    25.57   25.23  25.54  70176
# ...          ...    ...    ...      ...     ...    ...    ...
# 122569  20100813    ZMH  51.72     51.9   51.38  51.44  14561
# 122570  20100816    ZMH  51.13    51.47    50.6     51  13489
# 122571  20100817    ZMH  51.14     51.6   50.89  51.21  20498
# 122572  20100819    ZMH  51.63    51.63   50.17  50.22  18259
# 122573  20100820    ZMH  50.03    50.55   49.48  49.82  17792
#
# [122574 rows x 7 columns]

# %% [markdown]
# 2. Рассчитайте среднее значение показателей для каждого из столбцов c номерами 3-6.

# %%
pd2 = dataset[:, 2:]
print(pd.to_numeric(pd2[:,0], downcast='float').mean())
print(pd.to_numeric(pd2[:,1], downcast='float').mean())
print(pd.to_numeric(pd2[:,2], downcast='float').mean())
print(pd.to_numeric(pd2[:,3], downcast='float').mean())
print(pd.to_numeric(pd2[:,4], downcast='float').mean())
# Out:
# 42.595455
# 43.102245
# 42.054462
# 42.601864
# 81395.06

# %% [markdown]
# 3. Добавьте столбец, содержащий только число месяца, к которому относится дата.

# %%
import datetime as dt
from datetime import date
"""dates = pd1['date']
new_dt = pd.to_datetime(dates)
months = []
for i in new_dt:
    type(i)
    months.append(i.month)"""
temp_dt = pd.to_datetime(pd1['date'], format = '%Y%m%d')
pd1['month'] = temp_dt.dt.month
pd1
# Out:
#             date ticker   open     high     low  close volume  month
# 0       20090821      A   25.6    25.61   25.22  25.55  34758      8
# 1       20090824      A  25.64    25.74   25.33   25.5  22247      8
# 2       20090825      A   25.5     25.7  25.225  25.34  30891      8
# 3       20090826      A  25.32  25.6425  25.145  25.48  33334      8
# 4       20090827      A   25.5    25.57   25.23  25.54  70176      8
# ...          ...    ...    ...      ...     ...    ...    ...    ...
# 122569  20100813    ZMH  51.72     51.9   51.38  51.44  14561      8
# 122570  20100816    ZMH  51.13    51.47    50.6     51  13489      8
# 122571  20100817    ZMH  51.14     51.6   50.89  51.21  20498      8
# 122572  20100819    ZMH  51.63    51.63   50.17  50.22  18259      8
# 122573  20100820    ZMH  50.03    50.55   49.48  49.82  17792      8
#
# [122574 rows x 8 columns]

# %% [markdown]
# 4. Рассчитайте суммарный объем торгов для для одинаковых значений тикеров.

# %% [markdown]
# 5. Загрузите данные из файла sp500hst.txt и обозначьте столбцы в соответствии с содержимым: "date", "ticker", "open", "high", "low", "close", "volume". Добавьте столбец с расшифровкой названия тикера, используя данные из файла `sp_data2.csv` . В случае нехватки данных об именах тикеров корректно обработать их.

# %% [markdown]
# ## Лабораторная работа №2

# %% [markdown]
# ### Базовые операции с `DataFrame`

# %% [markdown]
# 1.1 В файлах `recipes_sample.csv` и `reviews_sample.csv` находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца с индексами в таблице `reviews` (безымянный столбец).

# %%
recipes = pd.read_csv('recipes_sample.csv', delimiter = ',')
reviews = pd.read_csv('reviews_sample.csv', delimiter = ',')
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id   submitted  n_steps  \
# 0               35193  2002-10-25      NaN
# 1               91970  2003-07-26      NaN
# ...

# %% [markdown]
# 1.2 Для каждой из таблиц выведите основные параметры:
# * количество точек данных (строк);
# * количество столбцов;
# * тип данных каждого столбца.

# %%
print(f'Кол-во строк в таблице recipes: {len(recipes)}')
print(f'Кол-во строк в таблице reviews: {len(reviews)}')

print(f'Кол-во столбцов в таблице recipes: {recipes.shape[1]}')
print(f'Кол-во столбцов в таблице reviews: {reviews.shape[1]}' + '\n')

print('Типы данных в таблице recipes: ')
print(*list(recipes[i].dtype for i in recipes.columns))
print('Типы данных в таблице reviews: ')
print(*list(reviews[i].dtype for i in reviews.columns))
# Out:
# Кол-во строк в таблице recipes: 30000
# Кол-во строк в таблице reviews: 126696
# Кол-во столбцов в таблице recipes: 8
# Кол-во столбцов в таблице reviews: 6
#
# Типы данных в таблице recipes:
# object int64 int64 int64 object float64 object float64
# Типы данных в таблице reviews:
# int64 int64 int64 object int64 object

# %% [markdown]
# 1.3 Исследуйте, в каких столбцах таблиц содержатся пропуски. Посчитайте долю строк, содержащих пропуски, в отношении к общему количеству строк.

# %%
num_nna = dict(zip(list(recipes.columns), list(recipes.count())))
for i in num_nna:
    print(f'Столбец {i} содержит пропуски: {num_nna[i] != len(recipes)}')
print(f'Количество строчек не содеержащих пропуски: {list(recipes.count(axis=1)).count(8)}. Доля таких строк от общего \
кол-ва: {list(recipes.count(axis=1)).count(8)/len(recipes)}')
# Out:
# Столбец name содержит пропуски: False
# Столбец id содержит пропуски: False
# Столбец minutes содержит пропуски: False
# Столбец contributor_id содержит пропуски: False
# Столбец submitted содержит пропуски: False
# Столбец n_steps содержит пропуски: True
# Столбец description содержит пропуски: True
# Столбец n_ingredients содержит пропуски: True
# Количество строчек не содеержащих пропуски: 12946. Доля таких строк от общего кол-ва: 0.4315333333333333

# %% [markdown]
# 1.4 Рассчитайте среднее значение для каждого из числовых столбцов (где это имеет смысл).

# %%
dict(zip(['minutes','n_steps', 'n_ingredients'], list(recipes.describe().loc['mean', i] for i in ['minutes','n_steps', 'n_ingredients'])))
# Out:
# {'minutes': 123.35813333333333,
#  'n_steps': 9.805582137161085,
#  'n_ingredients': 9.008285984848484}

# %% [markdown]
# 1.5 Создайте серию из 10 случайных названий рецептов.

# %%
rnd_names = (np.random.choice(recipes['name'], 10))
rnd_names
# Out:
# array(['cornbread casserole', 'barbecue skillet pork chops',
#        'crispy vegetables', 'la hacienda mexican chicken soup',
#        'dal makhani  spicy black lentils', 'blue cheese mussels',
#        'easy reuben sandwich slices', 'my favourite banana muffins',
#        'agua fresca de pepino', 'vodka creme brulee martini'],
#       dtype=object)

# %% [markdown]
# 1.6 Измените индекс в таблице `reviews`, пронумеровав строки, начиная с нуля.

# %%
#не совсем понял задание, строки ведь итак пронумерованы с нуля
print(reviews.index)
reviews
# Out:
# RangeIndex(start=0, stop=126696, step=1)
#         Unnamed: 0     user_id  recipe_id        date  rating  \
# 0           370476       21752      57993  2003-05-01       5
# 1           624300      431813     142201  2007-09-16       5
# 2           187037      400708     252013  2008-01-10       4
# 3           706134  2001852463     404716  2017-12-11       5
# 4           312179       95810     129396  2008-03-14       5
# ...            ...         ...        ...         ...     ...
# 126691     1013457     1270706     335534  2009-05-17       4
# 126692      158736     2282344       8701  2012-06-03       0
# 126693     1059834      689540     222001  2008-04-08       5
# 126694      453285  2000242659     354979  2015-06-02       5
# 126695      691207      463435     415599  2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# ...

# %% [markdown]
# 1.7 Выведите информацию о рецептах, время выполнения которых не больше 20 минут и кол-во ингредиентов в которых не больше 5.

# %%
recipes[((recipes.minutes <= 20) & (recipes.n_ingredients <= 5))]
# Out:
#                                                     name      id  minutes  \
# 28                                   quick biscuit bread  302399       20
# 60                         peas  fit for a king or queen  303944       20
# 90                     hawaiian sunrise           mimosa  100837        5
# 91            tasty dish s   banana pudding in 2 minutes  286484        2
# 94                                    1 minute meatballs   11361       13
# ...                                                  ...     ...      ...
# 29873  zip and steam red potatoes with butter and garlic  304922       13
# 29874                          ziplock vanilla ice cream   74250       10
# 29905                      zucchini and corn with cheese  256177       15
# 29980               zucchini with jalapeno monterey jack  320622       10
# 29983                          zucchini with serrano ham  162411       15
#
#        contributor_id   submitted  n_steps  \
# ...

# %% [markdown]
# ### Работа с датами в `pandas`

# %% [markdown]
# 2.1 Преобразуйте столбец `submitted` из таблицы `recipes` в формат времени. Модифицируйте решение задачи 1.1 так, чтобы считать столбец сразу в нужном формате.

# %%
import datetime as dt

# %%
# преобразование столбца с датой в формат времени
recipes.submitted = pd.to_datetime(recipes.submitted, format = '%Y-%M-%d')
print(f'Тип данных в столбце submitted: {recipes.submitted.dtype}')
recipes
# Out:
# Тип данных в столбце submitted: datetime64[ns]
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id           submitted  n_steps  \
# ...

# %%
#считывание из файла recipes.csv сразу же в нужном формате времени
recipes = pd.read_csv('recipes_sample.csv', delimiter = ',', parse_dates= ['submitted'])
'''parse_dates интерпретирует данные
в столбце submitted сразу же в формате даты'''
print('Типы данных в таблице recipes: ')
print(*list(recipes[i].dtype for i in recipes.columns))
recipes
# Out:
# Типы данных в таблице recipes:
# object int64 int64 int64 datetime64[ns] float64 object float64
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
# ...

# %% [markdown]
# 2.2 Выведите информацию о рецептах, добавленных в датасет не позже 2010 года.

# %%
recipes[recipes.submitted.dt.year <= 2010]
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29993                     zuni caf zucchini pickles  316950     2895
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# ### Работа со строковыми данными в `pandas`

# %% [markdown]
# 3.1  Добавьте в таблицу `recipes` столбец `description_length`, в котором хранится длина описания рецепта из столбца `description`.

# %%
recipes['description_length'] = pd.Series(len(i) for i in recipes.description.fillna(''))
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.2 Измените название каждого рецепта в таблице `recipes` таким образом, чтобы каждое слово в названии начиналось с прописной буквы.

# %%
recipes.name = pd.Series(i.capitalize() for i in recipes.name)
recipes
# Out:
#                                                name      id  minutes  \
# 0             George s at the cove  black bean soup   44123       90
# 1                Healthy for them  yogurt popsicles   67664       10
# 2                      I can t believe it s spinach   38798       30
# 3                              Italian  gut busters   35173       45
# 4          Love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie s holey rustic olive and cheddar bread  267661       80
# 29996          Zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   Zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   Zydeco soup  486161       60
# 29999        Cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.3 Добавьте в таблицу `recipes` столбец `name_word_count`, в котором хранится количество слов из названии рецепта (считайте, что слова в названии разделяются только пробелами). Обратите внимание, что между словами может располагаться несколько пробелов подряд.

# %%
import re
recipes['name_word_count'] = pd.Series(len(re.findall(r'\w+',i)) for i in recipes.name)
recipes
# Out:
#                                                name      id  minutes  \
# 0             George s at the cove  black bean soup   44123       90
# 1                Healthy for them  yogurt popsicles   67664       10
# 2                      I can t believe it s spinach   38798       30
# 3                              Italian  gut busters   35173       45
# 4          Love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie s holey rustic olive and cheddar bread  267661       80
# 29996          Zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   Zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   Zydeco soup  486161       60
# 29999        Cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# ### Группировки таблиц `pd.DataFrame`

# %% [markdown]
# 4.1 Посчитайте количество рецептов, представленных каждым из участников (`contributor_id`). Какой участник добавил максимальное кол-во рецептов?

# %%
n_recipes = recipes.groupby('contributor_id').count().name
mx = n_recipes.max()
for i in n_recipes.index:
    if n_recipes.loc[i] == mx:
        print(f'Участник {i} добавил максимальное кол-во рецептов')
        break
# Out:
# Участник 89831 добавил максимальное кол-во рецептов

# %% [markdown]
# 4.2 Посчитайте средний рейтинг к каждому из рецептов. Для скольких рецептов отсутствуют отзывы? Обратите внимание, что отзыв с нулевым рейтингом или не заполненным текстовым описанием не считается отсутствующим.

# %%
#Средний рейтинг каждого рецепта
reviews.groupby('recipe_id').rating.mean()
# Out:
# recipe_id
# 48        1.000000
# 55        4.750000
# 66        4.944444
# 91        4.750000
# 94        5.000000
#             ...
# 536547    5.000000
# 536610    0.000000
# 536728    4.000000
# 536729    4.750000
# 536747    0.000000
# Name: rating, Length: 28100, dtype: float64

# %%
#Кол-во рецептов, на которые не оставлено ни одного отзыва
zero_reviews = len(recipes) - len(reviews.groupby('recipe_id').review.count())
print(f'Кол-во рецептов без отзывов: {zero_reviews}')
# Out:
# Кол-во рецептов без отзывов: 1900

# %% [markdown]
# 4.3 Посчитайте количество рецептов с разбивкой по годам создания.

# %%
recipes
# Out:
#                                                name      id  minutes  \
# 0             George s at the cove  black bean soup   44123       90
# 1                Healthy for them  yogurt popsicles   67664       10
# 2                      I can t believe it s spinach   38798       30
# 3                              Italian  gut busters   35173       45
# 4          Love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie s holey rustic olive and cheddar bread  267661       80
# 29996          Zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   Zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   Zydeco soup  486161       60
# 29999        Cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %%
recipes.groupby(recipes.submitted.dt.year).id.count()
# Out:
# submitted
# 1999     275
# 2000     104
# 2001     589
# 2002    2644
# 2003    2334
# 2004    2153
# 2005    3130
# 2006    3473
# 2007    4429
# 2008    4029
# 2009    2963
# 2010    1538
# 2011     922
# 2012     659
# 2013     490
# 2014     139
# 2015      42
# 2016      24
# 2017      39
# 2018      24
# Name: id, dtype: int64

# %% [markdown]
# ### Объединение таблиц `pd.DataFrame`

# %% [markdown]
# 5.1 При помощи объединения таблиц, создайте `DataFrame`, состоящий из четырех столбцов: `id`, `name`, `user_id`, `rating`. Рецепты, на которые не оставлен ни один отзыв, должны отсутствовать в полученной таблице. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и попытавшись найти строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
#Создание новой таблицы по заданным критериям
new_table_1 = pd.merge(recipes, reviews, left_on='id', right_on='recipe_id')
new_table_1.drop(columns=['Unnamed: 0', 'minutes', 'contributor_id', 'submitted', 'n_steps', 'description', 'n_ingredients',
'description_length', 'name_word_count', 'recipe_id', 'date', 'review'], inplace=True)
new_table_1
# Out:
#                                           name      id  user_id  rating
# 0        George s at the cove  black bean soup   44123   743566       5
# 1        George s at the cove  black bean soup   44123    76503       5
# 2        George s at the cove  black bean soup   44123    34206       5
# 3           Healthy for them  yogurt popsicles   67664   494084       5
# 4           Healthy for them  yogurt popsicles   67664   303445       5
# ...                                        ...     ...      ...     ...
# 126691                             Zydeco soup  486161   305531       5
# 126692                             Zydeco soup  486161  1271506       5
# 126693                             Zydeco soup  486161   724631       5
# 126694                             Zydeco soup  486161   133174       5
# 126695  Cookies by design   cookies on a stick  298512   804234       1
#
# [126696 rows x 4 columns]

# %%
#Подтверждение отсутсвия рецептов, на которые нет отзывов
for i in recipes['id']:
    if i == 1144:
        print('В изначальной таблице RECIPES существует рецепт с ID 1144')
        break
        
        
for i in reviews['recipe_id']:
    if i == 1144:
        print('В изначальной таблице REVIEWS существует рецепт с ID 1144')
        break
print('В изначальной таблице REVIEWS НЕ существует рецепта с ID 1144, а значит на него не было оставлено ни одного отзыва')
    
    
for i in new_table_1['id']:
    if i == 1144:
        print('В итоговой таблице NEW_TABLE_1 существует рецепт с ID 1144')
        break
print('В итоговой таблице NEW_TABLE_1 НЕ существует рецепта с ID 1144, а значит код сработал верно и не добавил рецепты без \
отзывов в новую таблицу')
# Out:
# В изначальной таблице RECIPES существует рецепт с ID 1144
# В изначальной таблице REVIEWS НЕ существует рецепта с ID 1144, а значит на него не было оставлено ни одного отзыва
# В итоговой таблице NEW_TABLE_1 НЕ существует рецепта с ID 1144, а значит код сработал верно и не добавил рецепты без отзывов в новую таблицу

# %% [markdown]
# 5.2 При помощи объединения таблиц и группировок, создайте `DataFrame`, состоящий из трех столбцов: `recipe_id`, `name`, `review_count`, где столбец `review_count` содержит кол-во отзывов, оставленных на рецепт `recipe_id`. У рецептов, на которые не оставлен ни один отзыв, в столбце `review_count` должен быть указан 0. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и найдя строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
#создание новой таблицы
review_count = reviews.groupby('recipe_id').review.count()
temp_table1 = pd.merge(recipes, reviews, how = 'left', left_on='id', right_on='recipe_id')
temp_table1.drop(columns=['Unnamed: 0', 'minutes', 'contributor_id', 'submitted', 'n_steps', 'description', 'n_ingredients',
'description_length', 'name_word_count', 'recipe_id', 'date', 'review', 'user_id', 'rating'], inplace=True)
temp_table1.rename(columns = {'id':'recipe_id'}, inplace=True)
temp_table1.drop_duplicates(keep='first', inplace = True)
temp_data = {'recipe_id': dict(review_count).keys(),
            'review_count': dict(review_count).values()}
temp_table2 = pd.DataFrame(temp_data)

new_table_2 = pd.merge(temp_table1, temp_table2, how='left')
new_table_2 #новая таблица
# Out:
#                                                name  recipe_id  review_count
# 0             George s at the cove  black bean soup      44123           3.0
# 1                Healthy for them  yogurt popsicles      67664           8.0
# 2                      I can t believe it s spinach      38798           3.0
# 3                              Italian  gut busters      35173           1.0
# 4          Love is in the air  beef fondue   sauces      84797           8.0
# ...                                             ...        ...           ...
# 29995  Zurie s holey rustic olive and cheddar bread     267661           4.0
# 29996          Zwetschgenkuchen  bavarian plum cake     386977           2.0
# 29997   Zwiebelkuchen   southwest german onion cake     103312           6.0
# 29998                                   Zydeco soup     486161           6.0
# 29999        Cookies by design   cookies on a stick     298512           1.0
#
# [30000 rows x 3 columns]

# %%
#Подтверждение того, что в колонке review_count для рецептов без отзывов указано значение 0
#В прошлом номере мы поняли, что на рецепт с id 1144 нет ни одного отзыва
new_table_2.fillna(0.0, inplace=True)
new_table_2.query('recipe_id == 1144') #делаем запрос в датафрейм, находим строчку, соответствующую нужному рецепту и видим
#в столбце review_count значение 0, как и требовалось
# Out:
#                              name  recipe_id  review_count
# 25816  Steak   tomato basil pasta       1144           0.0

# %% [markdown]
# 5.3. Выясните, рецепты, добавленные в каком году, имеют наименьший средний рейтинг?

# %%
temp_table3 = pd.merge(recipes, reviews, how = 'left', left_on='id', right_on='recipe_id')
temp_table3.drop(columns=['Unnamed: 0', 'minutes', 'contributor_id', 'n_steps', 'description', 'n_ingredients',
'description_length', 'name_word_count', 'recipe_id', 'date', 'review', 'user_id', 'name', ], inplace=True)
a = temp_table3.groupby(temp_table3.submitted.dt.year).mean()
mn = min(a.rating)
print(mn)
#a.query('rating == `mx2`')
# Out:
# 2.75

# %% [markdown]
# ### Сохранение таблиц `pd.DataFrame`

# %% [markdown]
# 6.1 Отсортируйте таблицу в порядке убывания величины столбца `name_word_count` и сохраните результаты выполнения заданий 3.1-3.3 в csv файл.

# %%
recipes.sort_values(by='name_word_count', ascending=False).to_csv('sorted_recipes.csv')

# %% [markdown]
# 6.2 Воспользовавшись `pd.ExcelWriter`, cохраните результаты 5.1 и 5.2 в файл: на лист с названием `Рецепты с оценками` сохраните результаты выполнения 5.1; на лист с названием `Количество отзывов по рецептам` сохраните результаты выполнения 5.2.

# %%
with pd.ExcelWriter("new_tables_results.xlsx") as writer:
    new_table_1.to_excel(writer, sheet_name='Рецепты с оценками')
    new_table_2.to_excel(writer, sheet_name='Количество отзывов по рецептам')

# %% [markdown]
# #### [версия 2]
# * Уточнены формулировки задач 1.1, 3.3, 4.2, 5.1, 5.2, 5.3
